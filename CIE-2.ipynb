# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
card_df=pd.read_csv("clean_dataset.csv")
card_df
# Out:
#      Gender    Age    Debt  Married  BankCustomer         Industry Ethnicity  \
# 0         1  30.83   0.000        1             1      Industrials     White
# 1         0  58.67   4.460        1             1        Materials     Black
# 2         0  24.50   0.500        1             1        Materials     Black
# 3         1  27.83   1.540        1             1      Industrials     White
# 4         1  20.17   5.625        1             1      Industrials     White
# ..      ...    ...     ...      ...           ...              ...       ...
# 685       1  21.08  10.085        0             0        Education     Black
# 686       0  22.67   0.750        1             1           Energy     White
# 687       0  25.25  13.500        0             0       Healthcare    Latino
# 688       1  17.92   0.205        1             1  ConsumerStaples     White
# 689       1  35.00   3.375        1             1           Energy     Black
#
# ...

# %%
card_df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# ## univariate analysis for continuous variable

# %%
sns.histplot(card_df.Age,kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## univariate analysis for categorical variables

# %%
sns.countplot(card_df.Gender)
# Out:
# C:\Users\prati\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## Bivariate analysis for continuous vs continuous variable

# %%
sns.scatterplot(card_df.Age,card_df.YearsEmployed)
card_df[['Age','YearsEmployed']].corr()
# Out:
# C:\Users\prati\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#                     Age  YearsEmployed
# Age            1.000000       0.391464
# YearsEmployed  0.391464       1.000000

# %% [markdown]
# ## Bivariate analisis for continuous vs categorical

# %%
sns.kdeplot(data=card_df,x='Age',hue="Approved",fill=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Bivariate analysis for categorial vs categorial variable

# %%
sns.countplot(data=card_df,x='Gender',hue='Approved')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## Multivariate analysis for NUM-NUM- Categorical variable

# %%
sns.pairplot(card_df[['Age','Income','YearsEmployed','Gender','CreditScore']],hue='Gender')
